# %%
from grid_maze import GridNodes
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

g = GridNodes(10, 10, "WALL")
img = g.draw()
plt.figure(figsize=(10, 10))
plt.imshow(np.array(img))
plt.axis("off")
plt.title(f"Maze Grid ({10}x{10})")
plt.show()
# Out:
# Connecting (9, 9) to (8, 9)
# Connecting (9, 9) to (9, 8)
# Connecting (9, 8) to (9, 7)
# Connecting (9, 7) to (9, 6)
# Connecting (9, 7) to (8, 7)
# Connecting (9, 6) to (8, 6)
# Connecting (8, 9) to (8, 8)
# Connecting (8, 8) to (7, 8)
# Connecting (8, 6) to (8, 5)
# Connecting (9, 6) to (9, 5)
# Connecting (8, 5) to (7, 5)
# Connecting (7, 5) to (7, 6)
# Connecting (7, 6) to (6, 6)
# Connecting (7, 6) to (7, 7)
# Connecting (7, 5) to (6, 5)
# Connecting (6, 6) to (5, 6)
# Connecting (6, 6) to (6, 7)
# Connecting (8, 5) to (8, 4)
# Connecting (6, 7) to (5, 7)
# Connecting (7, 8) to (7, 9)
# Connecting (6, 5) to (6, 4)
# Connecting (6, 7) to (6, 8)
# Connecting (6, 8) to (6, 9)
# Connecting (7, 5) to (7, 4)
# Connecting (5, 7) to (4, 7)
# Connecting (6, 9) to (5, 9)
# Connecting (5, 6) to (5, 5)
# Connecting (7, 4) to (7, 3)
# Connecting (9, 5) to (9, 4)
# Connecting (5, 9) to (5, 8)
# Connecting (9, 4) to (9, 3)
# Connecting (5, 9) to (4, 9)
# Connecting (4, 7) to (3, 7)
# ...
